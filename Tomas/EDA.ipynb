# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_august = pd.read_csv("https://raw.githubusercontent.com/CathieLC/Happy_four_friends/main/Dataset/ManoMano%20-%20August%202021.csv?token=GHSAT0AAAAAABMXSZJMU35CES7HVZWAJODMYPRFTPA", low_memory=False)
df_september = pd.read_csv("https://raw.githubusercontent.com/CathieLC/Happy_four_friends/main/Dataset/ManoMano%20-%20September%202021.csv?token=GHSAT0AAAAAABMXSZJMUP5FCAR47B6L2AEQYPRFU5Q", low_memory=False)
df_october = pd.read_csv("https://raw.githubusercontent.com/CathieLC/Happy_four_friends/main/Dataset/ManoMano%20-%20October%202021.csv?token=GHSAT0AAAAAABMXSZJMRDZONS4ZZPZ4U72UYPRFVFQ", low_memory=False)
df_november = pd.read_csv("https://raw.githubusercontent.com/CathieLC/Happy_four_friends/main/Dataset/ManoMano%20-%20November%202021.csv?token=GHSAT0AAAAAABMXSZJM57XIDQDMXJ3CA5IKYPRFVMA", low_memory=False)

# %%
print(df_august.shape)
print(df_september.shape)
print(df_october.shape)
print(df_november.shape)
# Out:
# (17652, 35)
# (19867, 34)
# (24663, 34)
# (33000, 34)

# %%
df_august.columns
# Out:
# Index(['id', 'comment', 'original_comment', 'score', 'data_scale',
#        'data_source', 'created_at', 'date', 'day', 'month', 'is_mf', 'device',
#        'family', 'is_b2b', 'reason', 'browser', 'zipcode', 'category',
#        'language', 'platform', 'provider', 'first_order', 'nb_articles',
#        'csat_presales', 'shipping_fees', 'bv_transaction', 'payment_method',
#        'operating_system', 'last_paid_channel', 'has_presales_contact',
#        'shipping_fees_bucket', 'bv_transaction_bucket',
#        'has_manodvisor_contact', 'themes', 'tags'],
#       dtype='object')

# %%
df_september.columns
# Out:
# Index(['id', 'comment', 'original_comment', 'score', 'data_scale',
#        'data_source', 'created_at', 'date', 'day', 'month', 'is_mf', 'device',
#        'family', 'is_b2b', 'reason', 'browser', 'category', 'language',
#        'platform', 'provider', 'first_order', 'nb_articles', 'csat_presales',
#        'shipping_fees', 'bv_transaction', 'payment_method', 'operating_system',
#        'last_paid_channel', 'has_presales_contact', 'shipping_fees_bucket',
#        'bv_transaction_bucket', 'has_manodvisor_contact', 'themes', 'tags'],
#       dtype='object')

# %%
mano = pd.concat([df_august, df_september, df_october, df_november])

# %%
mano.shape
# Out:
# (95182, 35)

# %%
mano.head()
# Out:
#           id comment original_comment  score data_scale  \
# 0  295564331     NaN              NaN     10        NPS
# 1  295563489     NaN              NaN     10        NPS
# 2  295564358     NaN              NaN      8        NPS
# 3  295563988     NaN              NaN      5        NPS
# 4  295562040     NaN              NaN     10        NPS
#
#              data_source                created_at        date       day  \
# 0  Customer Effort Score  2021-08-01T00:02:13.000Z  2021-08-01  dimanche
# 1  Customer Effort Score  2021-08-01T00:04:10.000Z  2021-08-01  dimanche
# 2  Customer Effort Score  2021-08-01T00:15:48.000Z  2021-08-01  dimanche
# 3  Customer Effort Score  2021-08-01T02:04:17.000Z  2021-08-01  dimanche
# 4  Customer Effort Score  2021-08-01T02:38:07.000Z  2021-08-01  dimanche
#
#   month  ...  bv_transaction payment_method operating_system  \
# 0  août  ...          119,95         paypal         iOS 14.6
# 1  août  ...           99,99     mastercard       Windows 10
# ...

# %%
(mano.isna().sum()/mano.shape[0]).sort_values(ascending=False)
# Out:
# reason                    0.958227
# tags                      0.958028
# themes                    0.879221
# comment                   0.879105
# original_comment          0.876069
# zipcode                   0.814545
# last_paid_channel         0.007585
# is_b2b                    0.007081
# family                    0.000063
# provider                  0.000063
# category                  0.000063
# device                    0.000000
# is_mf                     0.000000
# score                     0.000000
# has_manodvisor_contact    0.000000
# bv_transaction_bucket     0.000000
# shipping_fees_bucket      0.000000
# has_presales_contact      0.000000
# data_scale                0.000000
# operating_system          0.000000
# payment_method            0.000000
# bv_transaction            0.000000
# shipping_fees             0.000000
# csat_presales             0.000000
# nb_articles               0.000000
# first_order               0.000000
# data_source               0.000000
# ...

# %%
# Représentetion graphique des isna()

plt.figure(figsize = (20, 10))
sns.heatmap(mano.isna(), cbar=False)
plt.show()

# %%
mano.describe(include='all')
# Out:
#                   id     comment original_comment         score data_scale  \
# count   9.518200e+04       11507            11796  95182.000000      95182
# unique           NaN        9922            10531           NaN          1
# top              NaN  All right.        Très bien           NaN        NPS
# freq             NaN          79               49           NaN      95182
# mean    3.355182e+08         NaN              NaN      8.969721        NaN
# std     2.117025e+07         NaN              NaN      1.545100        NaN
# min     2.955617e+08         NaN              NaN      0.000000        NaN
# 25%     3.201404e+08         NaN              NaN      8.000000        NaN
# 50%     3.370718e+08         NaN              NaN     10.000000        NaN
# 75%     3.552651e+08         NaN              NaN     10.000000        NaN
# max     3.690581e+08         NaN              NaN     10.000000        NaN
#
# ...

# %%
mano.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 95182 entries, 0 to 32999
# Data columns (total 35 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      95182 non-null  int64
#  1   comment                 11507 non-null  object
#  2   original_comment        11796 non-null  object
#  3   score                   95182 non-null  int64
#  4   data_scale              95182 non-null  object
#  5   data_source             95182 non-null  object
#  6   created_at              95182 non-null  object
#  7   date                    95182 non-null  object
#  8   day                     95182 non-null  object
#  9   month                   95182 non-null  object
#  10  is_mf                   95182 non-null  bool
#  11  device                  95182 non-null  object
#  12  family                  95176 non-null  object
#  13  is_b2b                  94508 non-null  object
# ...

# %%
for col in mano.columns:
    print(f'{col} : {mano[col].unique()}')
# Out:
# id : [295564331 295563489 295564358 ... 369054134 369056103 369042640]
# comment : [nan 'Clear and accurate... thank you.' 'All right.' ...
#  'All right, both the attention and the simplicity of the purchase.'
#  'Always correct and punctual!' 'Order ok, hopefully delivery ok']
# original_comment : [nan 'Clair et précis..... merci' 'Très bien' ...
#  'Todo correcto, tanto la atención como la sencillez de la compra.'
#  'Sempre corretti e puntuali!' 'Ordine ok, speriamo consegna ok']
# score : [10  8  5  9  7  3  0  6  2  1  4]
# data_scale : ['NPS']
# data_source : ['Customer Effort Score']
# created_at : ['2021-08-01T00:02:13.000Z' '2021-08-01T00:04:10.000Z'
#  '2021-08-01T00:15:48.000Z' ... '2021-11-30T23:49:53.000Z'
#  '2021-11-30T23:50:37.000Z' '2021-11-30T23:59:26.000Z']
# date : ['2021-08-01' '2021-08-02' '2021-08-03' '2021-08-04' '2021-08-05'
#  '2021-08-06' '2021-08-07' '2021-08-08' '2021-08-09' '2021-08-10'
# ...

# %%
mano[mano['reason'].notna()]
# Out:
#               id                                    comment  \
# 3      295563988                                        NaN
# 177    295564324                                        NaN
# 196    295562886                         too high shipments
# 221    295562182                                        NaN
# 243    295562642                    Delivery costs too high
# ...          ...                                        ...
# 32941  369052346                                        NaN
# 32959  369045716                                        NaN
# 32978  369043642                                        NaN
# 32981  369057301  My payment method didn't work as planned.
# 32995  369044254                                        NaN
#
#                                         original_comment  score data_scale  \
# 3                                                    NaN      5        NPS
# 177                                                  NaN      3        NPS
# ...
