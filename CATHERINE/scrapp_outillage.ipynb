# %%
import pandas as pd 
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd

# %%
df = pd.read_csv('manomano_outillages.csv')
df.drop(columns=['Unnamed: 0'], inplace=True)
df.head()
# Out:
#    COLIBRI_PRODUCT_GENERIC_ID FAMILY_NAME     CATEGORY_NAME  \
# 0                     2258908   Outillage  Outillage à main
# 1                     1747620   Outillage  Outillage à main
# 2                     4270561   Outillage  Outillage à main
# 3                     6545983   Outillage  Outillage à main
# 4                     1757107   Outillage  Outillage à main
#
#               SUB_CATEGORY_NAME            SUB_SUB_CATEGORY_NAME FORSALE  \
# 0            Outils de finition       Abrasif et papier de verre       Y
# 1              Clés et douilles       Douille et embout pour clé       Y
# 2  Outil de mesure électronique  Testeur et détecteur de tension       Y
# 3             Mesure et traçage                   Mètre dépliant       Y
# 4             Pince et tenaille       Pince coupante et tenaille       Y
#
#                                         NAME_ARTICLE  \
# 0   Toile emeri 18x28cm gr 1/80(x4)lot de 4 feuilles
# 1   Proxxon 3/8 bougies d'allumage utilisent Ø 16 mm
# ...

# %%
link_site = 'https://www.manomano.fr/p/pince-coupante-diagonale-avec-facette-knipex-77-72-115-115-mm-1-pcs-5526010?model_id=1757107'
https://www.manomano.fr/catalogue/p/xiaomi-mijia-wiha-24-in-1-tournevis-de-precision-s2-acier-outils-de-reparation-23665822

# %%
# try regex with index 0
liste = re.split('[/_]', df['MM_URL'][0])
liste[4]
# Out:
# 'ME2258908'

# %%
df_test = df.head(10)

# %%
df_test
# Out:
#    COLIBRI_PRODUCT_GENERIC_ID FAMILY_NAME     CATEGORY_NAME  \
# 0                     2258908   Outillage  Outillage à main
# 1                     1747620   Outillage  Outillage à main
# 2                     4270561   Outillage  Outillage à main
# 3                     6545983   Outillage  Outillage à main
# 4                     1757107   Outillage  Outillage à main
# 5                    23646715   Outillage  Outillage à main
# 6                       98538   Outillage  Outillage à main
# 7                    46386766   Outillage  Outillage à main
# 8                      628645   Outillage  Outillage à main
# 9                      609507   Outillage  Outillage à main
#
#                                   SUB_CATEGORY_NAME  \
# 0                                Outils de finition
# 1                                  Clés et douilles
# 2                      Outil de mesure électronique
# 3                                 Mesure et traçage
# ...

# %%
df_test['ref_article'] = df_test['MM_URL'].apply(lambda x: re.split('[/_]', x)[4])
# Out:
# C:\Users\cathe\AppData\Local\Temp/ipykernel_4580/3989033547.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['ref_article'] = df_test['MM_URL'].apply(lambda x: re.split('[/_]', x)[4])

# %%
df_test
# Out:
#    COLIBRI_PRODUCT_GENERIC_ID FAMILY_NAME     CATEGORY_NAME  \
# 0                     2258908   Outillage  Outillage à main
# 1                     1747620   Outillage  Outillage à main
# 2                     4270561   Outillage  Outillage à main
# 3                     6545983   Outillage  Outillage à main
# 4                     1757107   Outillage  Outillage à main
# 5                    23646715   Outillage  Outillage à main
# 6                       98538   Outillage  Outillage à main
# 7                    46386766   Outillage  Outillage à main
# 8                      628645   Outillage  Outillage à main
# 9                      609507   Outillage  Outillage à main
#
#                                   SUB_CATEGORY_NAME  \
# 0                                Outils de finition
# 1                                  Clés et douilles
# 2                      Outil de mesure électronique
# 3                                 Mesure et traçage
# ...

# %%
# add ref_article
df['ref_article'] = df['MM_URL'].apply(lambda x: re.split('[/_]', x)[4])

# %%
df.head()
# Out:
#    COLIBRI_PRODUCT_GENERIC_ID FAMILY_NAME     CATEGORY_NAME  \
# 0                     2258908   Outillage  Outillage à main
# 1                     1747620   Outillage  Outillage à main
# 2                     4270561   Outillage  Outillage à main
# 3                     6545983   Outillage  Outillage à main
# 4                     1757107   Outillage  Outillage à main
#
#               SUB_CATEGORY_NAME            SUB_SUB_CATEGORY_NAME FORSALE  \
# 0            Outils de finition       Abrasif et papier de verre       Y
# 1              Clés et douilles       Douille et embout pour clé       Y
# 2  Outil de mesure électronique  Testeur et détecteur de tension       Y
# 3             Mesure et traçage                   Mètre dépliant       Y
# 4             Pince et tenaille       Pince coupante et tenaille       Y
#
#                                         NAME_ARTICLE  \
# 0   Toile emeri 18x28cm gr 1/80(x4)lot de 4 feuilles
# 1   Proxxon 3/8 bougies d'allumage utilisent Ø 16 mm
# ...
